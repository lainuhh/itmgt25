# %%
import requests
import matplotlib.pyplot as plt
import time

lat = []
long = []

fig = plt.figure(figsize=(3, 3), facecolor='lightskyblue',
                 layout='constrained')
fig.suptitle('ISS Location')
ax = fig.add_subplot()
ax.set_title('Axes', loc='left', fontstyle='oblique', fontsize='medium')

for _ in range(100):
    
    r = requests.get('http://api.open-notify.org/iss-now.json')
    data = r.json()
    iter_lat = data['iss_position']['latitude']
    iter_long = data['iss_position']['longitude']
    lat.append(iter_lat)
    long.append(iter_long)
    ax.plot(lat, long)
    print(f"{_}   Added {iter_lat}, {iter_long} coordinates")
    time.sleep(10)
# Out:
# 0   Added -41.6842, -139.4010 coordinates
# 1   Added -41.3048, -138.6950 coordinates
# 2   Added -40.9206, -137.9977 coordinates
# 3   Added -40.5502, -137.3415 coordinates
# 4   Added -40.1569, -136.6609 coordinates
# 5   Added -39.7591, -135.9887 coordinates
# 6   Added -39.3762, -135.3562 coordinates
# 7   Added -38.9699, -134.6999 coordinates
# 8   Added -38.5595, -134.0517 coordinates
# 9   Added -38.1649, -133.4417 coordinates
# 10   Added -37.7468, -132.8089 coordinates
# 11   Added -37.3247, -132.1835 coordinates
# 12   Added -36.9193, -131.5949 coordinates
# 13   Added -36.4695, -130.9552 coordinates
# 14   Added -36.0572, -130.3806 coordinates
# 15   Added -35.6210, -129.7842 coordinates
# 16   Added -35.1814, -129.1948 coordinates
# 17   Added -34.7596, -128.6397 coordinates
# 18   Added -34.3137, -128.0635 coordinates
# 19   Added -33.8647, -127.4939 coordinates
# 20   Added -33.4341, -126.9572 coordinates
# 21   Added -32.9793, -126.4000 coordinates
# 22   Added -32.5215, -125.8489 coordinates
# 23   Added -32.0830, -125.3298 coordinates
# 24   Added -31.6198, -124.7903 coordinates
# 25   Added -31.1541, -124.2567 coordinates
# 26   Added -30.7081, -123.7538 coordinates
# 27   Added -30.2374, -123.2311 coordinates
# 28   Added -29.7643, -122.7139 coordinates
# 29   Added -29.3115, -122.2262 coordinates
# 30   Added -28.8338, -121.7191 coordinates
# 31   Added -28.3539, -121.2171 coordinates
# 32   Added -27.8718, -120.7200 coordinates
# 33   Added -27.4107, -120.2510 coordinates
# 34   Added -26.9245, -119.7631 coordinates
# 35   Added -26.4364, -119.2798 coordinates
# 36   Added -25.9696, -118.8236 coordinates
# 37   Added -25.4777, -118.3489 coordinates
# 38   Added -24.9840, -117.8784 coordinates
# 39   Added -24.5122, -117.4341 coordinates
# 40   Added -24.0151, -116.9716 coordinates
# 41   Added -23.5164, -116.5130 coordinates
# 42   Added -23.0160, -116.0581 coordinates
# 43   Added -22.5139, -115.6068 coordinates
# 44   Added -22.0343, -115.1803 coordinates
# 45   Added -21.5293, -114.7359 coordinates
# 46   Added -21.0229, -114.2949 coordinates
# 47   Added -20.5394, -113.8780 coordinates
# 48   Added -20.0304, -113.4434 coordinates
# 49   Added -19.5201, -113.0119 coordinates
# 50   Added -19.0330, -112.6036 coordinates
# 51   Added -18.5203, -112.1779 coordinates
# 52   Added -18.0309, -111.7749 coordinates
# 53   Added -17.5160, -111.3545 coordinates
# 54   Added -17.0000, -110.9367 coordinates
# 55   Added -16.5075, -110.5411 coordinates
# 56   Added -15.9894, -110.1282 coordinates
# 57   Added -15.4704, -109.7176 coordinates
# 58   Added -14.9504, -109.3092 coordinates
# 59   Added -14.4295, -108.9030 coordinates
# 60   Added -13.9077, -108.4989 coordinates
# 61   Added -13.4099, -108.1159 coordinates
# 62   Added -12.8367, -107.6776 coordinates
# 63   Added -12.1876, -107.1849 coordinates
# 64   Added -11.6875, -106.8076 coordinates
# 65   Added -11.1618, -106.4132 coordinates
# 66   Added -10.6354, -106.0202 coordinates
# 67   Added -10.1085, -105.6289 coordinates
# 68   Added -9.6061, -105.2574 coordinates
# 69   Added -9.0780, -104.8687 coordinates
# 70   Added -8.5494, -104.4813 coordinates
# 71   Added -8.0455, -104.1134 coordinates
# 72   Added -7.5160, -103.7282 coordinates
# 73   Added -6.9859, -103.3440 coordinates
# 74   Added -6.4808, -102.9789 coordinates
# 75   Added -5.9500, -102.5965 coordinates
# 76   Added -5.4189, -102.2150 coordinates
# 77   Added -4.9127, -101.8522 coordinates
# 78   Added -4.3810, -101.4720 coordinates
# 79   Added -3.8490, -101.0923 coordinates
# 80   Added -3.3422, -100.7313 coordinates
# 81   Added -2.8098, -100.3525 coordinates
# 82   Added -2.2772, -99.9743 coordinates
# 83   Added -1.7699, -99.6142 coordinates
# 84   Added -1.2371, -99.2364 coordinates
# 85   Added -0.7042, -98.8588 coordinates
# 86   Added -0.1713, -98.4812 coordinates
# 87   Added 0.3363, -98.1216 coordinates
# 88   Added 0.8693, -97.7440 coordinates
# 89   Added 1.4023, -97.3662 coordinates
# 90   Added 1.9098, -97.0062 coordinates
# 91   Added 2.4427, -96.6279 coordinates
# 92   Added 2.9753, -96.2494 coordinates
# 93   Added 3.5079, -95.8703 coordinates
# 94   Added 4.0149, -95.5089 coordinates
# 95   Added 4.5473, -95.1287 coordinates
# 96   Added 5.0539, -94.7663 coordinates
# 97   Added 5.5855, -94.3849 coordinates
# 98   Added 6.1170, -94.0028 coordinates
# 99   Added 6.6480, -93.6198 coordinates
